# %%
import http.server
import socketserver

port = 80
hostname = "localhost"

with socketserver.TCPServer((hostname, port), http.server.SimpleHTTPRequestHandler) as httpd:
    print(f"Serving web pages on {hostname} through port {port}")
    print(f"Try this: http://{hostname}:{port}")
    httpd.serve_forever()
# Out:
# Serving web pages on localhost through port 80
# Try this: http://localhost:80
# 127.0.0.1 - - [03/Feb/2019 22:06:28] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:06:35] "GET /www.tdcj.texas.gov/death_row/dr_executed_offenders.html HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:09:27] "GET /www.tdcj.texas.gov/death_row/dr_executed_offenders.html HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:22:40] "GET /www.tdcj.texas.gov/death_row/dr_info/clarktroylast.html HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:22:40] "GET /www.tdcj.texas.gov/stylesheets/global.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:22:40] "GET /www.tdcj.texas.gov/stylesheets/content.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:22:40] "GET /www.tdcj.texas.gov/stylesheets/menu_style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Feb/2019 22:22:40] "GET /www.tdcj.texas.gov/javascripts/google_search.js HTTP/1.1" 200 -
# ...
